# %%
import pickle
import networkx as nx
import matplotlib.pyplot as plt

# %%
# with open('test.pickle', 'rb') as f:
#     # The protocol version used is detected automatically, so we do not
#     # have to specify it.
#     data = pickle.load(f)

# %%
with open('graph.cPickle', 'rb') as f:
    # The protocol version used is detected automatically, so we do not
    # have to specify it.
    data = pickle.load(f)
    
data.remove_nodes_from(["INITIAL TIME","TIME STEP","SAVEPER","Time",
                             "TIME STEP","FINAL TIME"])

# %%
nx.draw_networkx(data)
plt.show()

# %%
1+1
# Out:
# 2

# %%
from Loopset import *

# %%
cycleGraphs = cycleGraph(data)

# %%
for i,x in enumerate(cycleGraphs):
    print(i,x)
# Out:
# 0

# %%
for graph in cycleGraphs:
    sils = SILS(graph)
    for entry in sils:
        print (entry)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-09708c11f869> in <module>()
#       1 for graph in cycleGraphs:
# ----> 2     sils = SILS(graph)
#       3     for entry in sils:
#       4         print (entry)
#
# C:\Users\Gebruiker\Dropbox\MSc EPA\EPA1341 Advanced System Dynamics\sils\Loopset.py in SILS(graph)
#     145     A = prt.adj(graph)
#     146     A = np.asarray(A)
# --> 147     loops = geodetic(graph)
#     148     nodes = graph.nodes()
#     149
#
# C:\Users\Gebruiker\Dropbox\MSc EPA\EPA1341 Advanced System Dynamics\sils\Loopset.py in geodetic(graph)
#     124
#     125         for entry in indices:
# --> 126             pairs.append([nodes[entry[0,0]],nodes[entry[0,1]]])
#     127         already_seen = []
#     128
#
# IndexError: too many indices for array

# %%
# %load "Loopset.py"
