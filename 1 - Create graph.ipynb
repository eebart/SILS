# %% [markdown]
# # Usage
#
# Usage for developing a causal map based on a vensim model.

# %%
import toCausal
# Out:
# both single and double precision vensim available, using single

# %%
graph = toCausal.build_causal_map('.','test.vpm')
toCausal.save_to_pickle(graph, 'test.pickle')
# Out:
# done

# %% [markdown]
# # Verify Visually
#
# The code below allows you to verify the resulting graph.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
nx.draw_networkx(graph)
plt.show()
